# %%
from curie_calculator import *

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
FAKE_MAGNETIC_ATOMS = ['Po', 'Mn']
input_folder = 'Bi-Mn/'
num_of_structures = 12
SPIN = 5/2

# %%
out_dict = get_results(input_folder, num_of_structures, FAKE_MAGNETIC_ATOMS, SPIN)
# Out:
# 100%|██████████| 12/12 [02:45<00:00, 13.82s/it]

# %%
abs_tc = np.array([abs(i) for i in out_dict['Tc_list']])

# %%
abs_tc.mean()
# Out:
# 285.38088586194397

# %%
abs_tc.max()
# Out:
# 1519.1600665087872

# %%
plt.figure(figsize=(10, 8), dpi=100)
plt.scatter(range(174), out_dict['Tc_list'])
plt.grid(alpha=.4)
