# %%
def magnetic_symm_checker():
    pass

# %%
ls
# Out:
# INPUT.txt                enumlib/                 main_plotter.py
# README.md                examples/                main_runner.py
# __pycache__/             install.sh*              main_test.ipynb
# cleaner.py               jobscript.sh             plotter.ipynb
# curie_calculator.py      magnetic_symmetry.ipynb

# %%
with open('examples/EuO/vasp_inputs/afm1/OUTCAR') as in_f:
    data = in_f.readlines()

# %%
data
# Out:
# [' vasp.5.4.4.18Apr17-6-g9f103f2a35 (build Apr 28 2018 00:24:27) complex          \n',
#  '  \n',
#  ' executed on             LinuxIFC date 2021.03.23  16:56:30\n',
#  ' running on    8 total cores\n',
#  ' distrk:  each k-point on    8 cores,    1 groups\n',
#  ' distr:  one band on NCORES_PER_BAND=   4 cores,    2 groups\n',
#  '\n',
#  '\n',
#  '--------------------------------------------------------------------------------------------------------\n',
#  '\n',
#  '\n',
#  ' INCAR:\n',
#  ' POTCAR:    PAW_PBE Eu 23Dec2003                  \n',
#  ' POTCAR:    PAW_PBE O 08Apr2002                   \n',
#  ' POTCAR:    PAW_PBE Eu 23Dec2003                  \n',
#  '   SHA256 =  ed303d27e7c5191953f9b15539336e6f36d9037c1d2e92e80c13d733697cb93d Eu\n',
#  '   COPYR  = (c) Copyright 23Dec2003 Georg Kresse                                \n',
#  '   COPYR  = This file is part of the software VASP. Any use, copying, and all ot\n',
# ...
