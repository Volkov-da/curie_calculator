        [-4,  2],
        [ 6,  0],
        [ 0, -4],
        [-2,  0],
        [ 2, -2],
        [-2,  0],
        [ 6,  0],
        [ 0,  4]]),
 'z1': 12,
 'z2': 12,
 'z3': 6}

# %%
def plot_TCs(TCs:list, input_folder: str):
    plt.figure(figsize=(8 ,6), dpi =100)
    plt.scatter(range(1, len(TCs) + 1), TCs, c='red')
    plt.ylabel('$T_C, K$', fontsize=16)
    plt.grid(alpha=.4)

    text = f'mean: {TCs.mean():.2f} K\nmax  : {TCs.max():.2f} K\nmin   : {TCs.min():.2f} K'
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

    plt.text(1, max(TCs),text, verticalalignment='top' , bbox=props)
    plt.xticks([])
    plt.savefig(os.path.join(input_folder, 'Tc_plot.pdf'))

def plot_Etot(energies_afm : list, nn_matrix : list, input_folder: str):
    x = range(1, len(energies_afm) + 1)
    plt.figure(figsize=(8, 6), dpi=100)
    plt.scatter(x, energies_afm)
    plt.grid(alpha=.4)
    plt.xlabel('afm structure nn list')
    plt.ylabel('$E_{tot}, eV$', fontsize=16)
        
    text = f"""
$dE$    :  {(energies_afm.max() - energies_afm.min()) * 1000 :.2f}   meV
max : {energies_afm.max() * 1000:.2f}  meV
min  : {energies_afm.min() * 1000:.2f}   meV
"""
    plt.xticks(x, nn_matrix, rotation=45, ha='right')
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    plt.text(1, min(energies_afm),text, verticalalignment='bottom' , bbox=props)
    plt.savefig(os.path.join(input_folder, 'Etot_plot.pdf'))

def plot_E_geom(Eg_list: list, combination_list : list, input_folder : str):
    
    E_geom = np.array(Eg_list) * 1000
    E_geom_norm = E_geom - E_geom.min()
    max_E_geom = max(E_geom)
    min_E_geom = min(E_geom)
    dE_geom  = max_E_geom - min_E_geom
    x_label = range(1, len(EuO_dict['Eg_list']) + 1)

    text = f"""
    $dE$    :  {(max_E_geom - min_E_geom):.2f}   meV
    max : {max_E_geom:.2f}  meV
    min  : {min_E_geom:.2f}   meV
    """
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

    #plotting
    plt.figure(figsize=(8, 6), dpi=100)
    plt.scatter(x_label, E_geom_norm)
    plt.title('Normalized energy without exchange coupling')
    plt.ylabel('Eg, meV')
    plt.text(1, max(E_geom_norm),text, verticalalignment='top' , bbox=props)
    plt.xticks(x_label, combinations, rotation=45, ha='right')
    plt.grid(alpha=.4)
    plt.savefig(os.path.join(input_folder, 'Egeom_plot.pdf'))

# %%
plot_TCs(EuO_dict['Tc_list'], input_folder='examples/EuO/')
plot_TCs(Ni_dict['Tc_list'], input_folder='examples/Ni/')
plot_TCs(Bi_Mn_dict['Tc_list'], input_folder='examples/Bi-Mn/')

# %%
plot_Etot(EuO_dict['energies_afm'], EuO_dict['nn_matrix'], input_folder='examples/EuO/')
plot_Etot(Ni_dict['energies_afm'], Ni_dict['nn_matrix'], input_folder='examples/Ni/')
plot_Etot(Bi_Mn_dict['energies_afm'], Bi_Mn_dict['nn_matrix'], input_folder='examples/Bi-Mn/')
# Out:
# /Users/dmitry.volkov/.pyenv/versions/3.8.6/lib/python3.8/site-packages/matplotlib/text.py:1163: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# /Users/dmitry.volkov/.pyenv/versions/3.8.6/lib/python3.8/site-packages/matplotlib/text.py:1163: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# /Users/dmitry.volkov/.pyenv/versions/3.8.6/lib/python3.8/site-packages/matplotlib/text.py:1163: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# /Users/dmitry.volkov/.pyenv/versions/3.8.6/lib/python3.8/site-packages/matplotlib/text.py:1163: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]
plt.scatter(x, y)
plt.margins(1)
